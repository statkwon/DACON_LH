# %% [markdown]
# ## Building Foundation: Importing library

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import optuna
import matplotlib as mpl ; mpl.rcParams['axes.unicode_minus'] = False
import matplotlib.pyplot as plt ; plt.rcParams['font.family'] = 'AppleGothic'
# %matplotlib inline
from sklearn.preprocessing import RobustScaler, StandardScaler
from sklearn.model_selection import train_test_split, StratifiedKFold, KFold, cross_val_score
from sklearn.metrics import mean_absolute_error
from pycaret.regression import *
from catboost import CatBoostRegressor, Pool
from optuna import Trial
from optuna.samplers import TPESampler
from impyute.imputation.cs import mice

# %%
### Public Data importing(myhome_xyfill은 크롤링 데이터입니다.)
code_age_gender = pd.read_csv('한국토지주택공사_임대주택 단지별 연령대별 성별정보_20210511.csv', encoding='CP949')
myhome_xyfill = pd.read_csv('myhome_xyfill.csv').drop_duplicates()
data = pd.read_csv('임대주택_단지_조회.csv')

### Original Data importing(오류 데이터 제거 포함)
age_gender_info = pd.read_csv('age_gender_info.csv')
train = pd.read_csv('train.csv')
train_error = ['C2085', 'C1397', 'C2431', 'C1649', 'C1036', 'C1095', 'C2051', 'C1218', 'C1894', 'C2483', 'C1502', 'C1988']
train = train[~train['단지코드'].isin(train_error)].reset_index(drop=True)
test = pd.read_csv('test.csv')
test_error = ['C2675', 'C2335', 'C1327']
test = test[~test['단지코드'].isin(test_error)].reset_index(drop=True)
print(f'Train Set: {train.shape} | Test Set: {test.shape}')
# Out:
# Train Set: (2869, 15) | Test Set: (1008, 14)

# %% [markdown]
# ## Building Foundation: Importing data and building function

# %%
### Public Data importing(myhome_xyfill은 크롤링 데이터입니다.)
code_age_gender = pd.read_csv('한국토지주택공사_임대주택 단지별 연령대별 성별정보_20210511.csv', encoding='CP949')
myhome_xyfill = pd.read_csv('myhome_xyfill.csv').drop_duplicates()
data = pd.read_csv('임대주택_단지_조회.csv')

### Original Data importing(오류 데이터 제거 포함)
age_gender_info = pd.read_csv('age_gender_info.csv')
train = pd.read_csv('train.csv')
train_error = ['C2085', 'C1397', 'C2431', 'C1649', 'C1036', 'C1095', 'C2051', 'C1218', 'C1894', 'C2483', 'C1502', 'C1988']
train = train[~train['단지코드'].isin(train_error)].reset_index(drop=True)
test = pd.read_csv('test.csv')
test_error = ['C2675', 'C2335', 'C1327']
test = test[~test['단지코드'].isin(test_error)].reset_index(drop=True)
print(f'Train Set: {train.shape} | Test Set: {test.shape}')

### Function
def code_name(df):
    #myhome 데이터의 필요한 부분만 긁어오기
    myhome = myhome_xyfill[['rnAdres','hsmpNm','hshldCo','suplyTyNm', '공급면적(전용)','임대보증금','임대료', 'x','y','준공일자']]
    myhome.columns= ['주소', '단지명', '총세대수', '공급유형', '전용면적','임대보증금','임대료','경도','위도','준공일자']
    #공급유형 및 지역 변수 설정
    myhome.loc[myhome['공급유형']=='50년임대', '공급유형'] = '공공임대(50년)'
    myhome.loc[myhome['공급유형']=='10년임대', '공급유형'] = '공공임대(10년)'
    myhome.loc[myhome['공급유형']=='5년임대', '공급유형'] = '공공임대(5년)'
    myhome['지역'] = myhome['주소'].str.split(' ').str[0]
    # 총세대수 -> 전용면적별세대수합 생성
    myhome_grouped = myhome[['주소','단지명','총세대수']].drop_duplicates()
    myhome_grouped = myhome_grouped.groupby(['단지명','주소'], as_index=False).sum()[['단지명','주소','총세대수']]
    myhome = pd.merge(myhome, myhome_grouped, on=['단지명','주소'], how='left')
    myhome.drop(['총세대수_x'], axis=1, inplace=True)
    myhome.rename(columns={'총세대수_y':'전용면적별세대수합'}, inplace=True)
    # First Match: 지역, 전용면적별세대수합, 공급유형, 전용면적 겹치는 것 중 유니크 382단지
    df = df.drop(['전용면적별세대수합'],axis=1)
    df = df.rename(columns={'전용면적별세대수합_myhome':'전용면적별세대수합'})
    home_merged = pd.merge(df, myhome, on=['지역', '전용면적별세대수합', '공급유형', '전용면적'])
    home_unq = home_merged.groupby(['단지코드']).nunique()
    code_unq = home_unq.index[np.where(home_unq['단지명']==1)]
    name_unq = home_merged[home_merged['단지코드'].isin(code_unq)]['단지명'].unique()
    home_unq.reset_index(drop=True, inplace=True)
    #Second Match: 지역, 공급유형, 전용면적, 임대보증금, 임대료 겹치는 것 중 전용면적별세대수 차이가 적은것
    home_unk = pd.merge(df, myhome, on=['지역','공급유형','전용면적','임대보증금','임대료'])
    home_unk = home_unk[~home_unk['단지코드'].isin(code_unq)]
    home_unk = home_unk[~home_unk['단지명'].isin(name_unq)]
    home_unk['전용면적별세대수차']=abs(home_unk['전용면적별세대수합_x']-home_unk['전용면적별세대수합_y'])
    home_unk = home_unk.groupby(['단지코드','단지명','주소','위도','경도','준공일자','전용면적별세대수차']).nunique('전용면적')['전용면적'].reset_index()
    home_unk = home_unk.loc[home_unk.groupby('단지코드').전용면적별세대수차.idxmin()]

    first_match = home_merged[home_merged['단지코드'].isin(code_unq)][['단지명','단지코드','주소','위도','경도','준공일자']].drop_duplicates()
    second_match = home_unk[['단지명','단지코드','주소','위도','경도','준공일자']].drop_duplicates()
    match = pd.concat([first_match, second_match],axis=0).reset_index(drop=True)

    # Final Match: 남은 것중에 지역과 공급유형이 동일하고 전용면적별세대수합 차이가 가장 적은것
    for_match = df[~df['단지코드'].isin(match['단지코드'])][['단지코드','지역','공급유형','전용면적별세대수합']].drop_duplicates()
    list_match =[]
  
    for code in for_match['단지코드'].unique():
        for_dict = for_match[for_match['단지코드']==code]
        rg = list(for_dict['지역'].values)
        sp = list(for_dict['공급유형'].values)
        if (sp[0]=='공공임대(분납)'):
            sp = ['공공임대(10년)'] # Myhome에는 공공임대(분납)이 없으므로
        nh = list(for_dict['전용면적별세대수합'].values)[0]
        myhome_match = myhome[(myhome['지역'].isin(rg))&(myhome['공급유형'].isin(sp))]
        myhome_match = list(myhome_match.loc[abs(myhome_match['전용면적별세대수합']-nh).idxmin()][['단지명','주소','위도','경도','준공일자']])
        list_match.append([code]+myhome_match)

    final_match = pd.DataFrame(list_match, columns=['단지코드','단지명','주소','위도','경도','준공일자'])
    match = pd.concat([match, final_match],axis=0).reset_index(drop=True)
    df = pd.merge(df, match, on=['단지코드'])
    df = df.fillna('0')
    return(df)

def total_member(df):
    # age_gender에서 주소, 단지명, 총입주민수, 주소_mod만 추출하기
    df_address = df[['주소','총세대수','단지명']].drop_duplicates().reset_index(drop=True)
    age_gender = code_age_gender[code_age_gender['주택유형']=='아파트']
    age_gender = age_gender.iloc[:,3:].drop(['주택유형','총세대수'],axis=1) 
    age_gender.rename(columns={'도로명주소':'주소', '주택명':'단지명'}, inplace=True)
    age_gender = age_gender[age_gender['주소'].notnull()]
    age_gender['단지명'] = age_gender['단지명'].str.replace(' ','')
    age_gender['총입주민수'] = age_gender.set_index(['단지명','주소']).apply(sum,axis=1).values
    age_gender = age_gender[['주소','단지명','총입주민수']].groupby(['주소','단지명']).sum().reset_index()
    age_gender['주소_mod'] = [''.join(elem[:-1]) for elem in age_gender['주소'].str.split()]

    # df에서 주소, 단지명, 주소_mod만 추출하기
    df_address['단지명_origin'] = df_address['단지명']
    df_address['단지명'] = df_address['단지명'].str.replace(' ','')
    df_address['주소_mod'] = [''.join(elem[:-1]) for elem in df_address['주소'].str.split()]
    df_address['총입주민수'] = None

    for i in range(df_address.shape[0]):
        add = df_address['주소'][i]
        cod = df_address['단지명'][i]
        try: 
            df_address['총입주민수'][i] = age_gender['총입주민수'][np.where((age_gender['주소']==add)&(age_gender['단지명']==cod))[0][0]]
        except:
            try: 
                add2 = df_address['주소_mod'][i]
                df_address['총입주민수'][i] = age_gender['총입주민수'][np.where((age_gender['주소_mod']==add2)&(age_gender['단지명']==cod))[0][0]]
            except:
                try: 
                    df_address['총입주민수'][i] = age_gender['총입주민수'][np.where(age_gender['주소']==add)[0][0]]
                except: pass
    # df_check = df_address[df_address.notnull().all(axis=1)]
    #((df_check['총입주민수'] / df_check['총세대수']).astype(float)).describe().round(1) # df_address[df_address.isnull().any(axis=1)] : 1.8
    for i in range(df_address.shape[0]):
        if ((df_address['총입주민수'][i]!=df_address['총입주민수'][i])|(df_address['총입주민수'][i]==None)):
            df_address['총입주민수'][i] = df_address['총세대수'][i] * 1.8

    df_address = df_address.drop(['단지명'],axis=1)
    df_address = df_address.rename(columns={'단지명_origin':'단지명'})
    df = pd.merge(df, df_address[['단지명','총입주민수']], on='단지명', how='left')

    for i in range(df.shape[0]):
        if ((df['총입주민수'][i]!=df['총입주민수'][i])|(df['총입주민수'][i]==None)):
            df['총입주민수'][i] = df['총세대수'][i] * 1.8

    df['총입주민수']=df['총입주민수'].astype(float)
    return(df)

#준공후 현재까지의 시간 차이를 월단위로 계산한 '준공후기간(월)' 변수 생성
def add_build_date(df):
    #준공일자 글자길이 7이면 (ex. 2020-01 까지만 존재)'-01' 추가해주기
    df.loc[df['준공일자'].str.len()==7, '준공일자'] = df.loc[df['준공일자'].str.len()==7, '준공일자']+str('-01')
    #준공일자 글자길이 5이면 (ex. 2020- 까지만 존재)-01-01'추가해주기
    df.loc[df['준공일자'].str.len()==5, '준공일자'] = df.loc[df['준공일자'].str.len()==5, '준공일자']+str('01-01')
    df.loc[df['준공일자'].notnull(),'준공일자'] = df.loc[df['준공일자'].notnull(),'준공일자'].str.replace('-','').astype('int64')
    #준공일자 지나치게 오래된것은 오류로 기입된 것이라 판단, NA로 대체.
    df.loc[df['준공일자']<=19700101, '준공일자'] = np.nan
    
    df.loc[df['준공일자'].notnull(),'년'] = df.loc[df['준공일자'].notnull(),'준공일자']//10000
    df.loc[df['준공일자'].notnull(),'월'] = df.loc[df['준공일자'].notnull(),'준공일자']//100 - df.loc[df['준공일자'].notnull(),'년']*100
    df.loc[df['준공일자'].notnull(),'준공후기간(월)'] = 2021*12 + 7 -(df.loc[df['준공일자'].notnull(),'년']*12 + df.loc[df['준공일자'].notnull(),'월'])
    df = df.drop(['준공일자', '년', '월'], axis=1)
    return(df)

#'입주후기간(월)' 변수 생성
def add_in_date(df):
    df_wo_dup = df.drop_duplicates(subset=['단지코드'])[['단지코드', '지역', '전용면적별세대수합']].reset_index(drop=True)
    idx = np.column_stack([df.drop_duplicates(subset=['단지코드'])[['지역', '전용면적별세대수합']].reset_index(drop=True), range(len(df_wo_dup))])
    df_wo_dup['단지명2'] = None
    df_wo_dup['입주후기간(월)'] = None
    for i, j, k in idx:
        if data.loc[(data['지역'] == i) & (data['전용면적별세대수합'] == j), '단지명2'].nunique() == 1:
            df_wo_dup.iloc[k, df_wo_dup.columns.get_loc('단지명2')] = data.loc[(data['지역'] == i) & (data['전용면적별세대수합'] == j), '단지명2'].unique()[0]
            df_wo_dup.iloc[k, df_wo_dup.columns.get_loc('입주후기간(월)')] = data.loc[(data['지역'] == i) & (data['전용면적별세대수합'] == j), '입주후기간(월)'].unique()[0]
    
    null = df_wo_dup[df_wo_dup['단지명2'].isnull()].reset_index(drop=True) #단지명 안붙은애들 null로 저장
    data_hhset = data[['단지명2', '전용면적']].groupby(['단지명2'])['전용면적'].apply(list) 
    data_hhset = pd.DataFrame(data_hhset)
    data_hhset = pd.merge(data_hhset, data[['단지명2', '지역', '전용면적별세대수합', '입주후기간(월)']], on='단지명2')
    data_hhset = data_hhset[['단지명2', '지역', '전용면적별세대수합', '전용면적','입주후기간(월)']]
    data_hhset = data_hhset.drop_duplicates(['단지명2']).reset_index(drop=True)

    idx = null['단지코드'].unique()
    for i in range(len(idx)):
        areaset_df = set(df.loc[df['단지코드'] == idx[i], '전용면적'])
        region = null.loc[i, '지역']
        total_hh2 = null.loc[i,'전용면적별세대수합']
        same = data_hhset.loc[(data_hhset['지역'] == region) & (data_hhset['전용면적별세대수합'] == total_hh2)].reset_index(drop=True)
        diff = []
        if len(same.index) != 0:
            for j in range(len(same)):
                areaset_data = set(same.loc[j, '전용면적'])
                diff.append(len(areaset_df - areaset_data))
            null.loc[i, '단지명2'] = same.loc[np.argmin(diff), '단지명2']
            null.loc[i, '입주후기간(월)'] = same.loc[np.argmin(diff), '입주후기간(월)']

    for i in range(len(df_wo_dup)):
        if df_wo_dup.iloc[i, df_wo_dup.columns.get_loc('단지명2')] == None:
            df_wo_dup.iloc[i, df_wo_dup.columns.get_loc('단지명2')] = null.loc[null['단지코드'] == df_wo_dup.iloc[i, df_wo_dup.columns.get_loc('단지코드')], '단지명2']
            df_wo_dup.iloc[i, df_wo_dup.columns.get_loc('입주후기간(월)')] = null.loc[null['단지코드'] == df_wo_dup.iloc[i, df_wo_dup.columns.get_loc('단지코드')], '입주후기간(월)']
        else:
            pass

    df = pd.merge(df, df_wo_dup[['단지코드', '단지명2', '입주후기간(월)']], how='left', on='단지코드')

    code_name = df['단지코드'].unique()
    for i in range(len(code_name)):
        dat = df.loc[df['단지코드'] == code_name[i],:]
        if (dat.shape[0] != dat.단지명2.isnull().sum()) & (dat.shape[0] != dat.단지명2.notnull().sum()):
            df.loc[df['단지코드'] == code_name[i],'단지명2'] = dat.loc[dat['단지명2'].notnull(),'단지명2']
            df.loc[df['단지코드'] == code_name[i],'입주후기간(월)'] = dat.loc[dat['단지명2'].notnull(),'입주후기간(월)']
        else:
            pass
    
    df['입주후기간(월)'] = df['입주후기간(월)'].astype('float64')
    df.reset_index(drop=True, inplace=True)
    # print(round(df.loc[df['단지명2'].isnull(), '단지코드'].nunique()/df['단지코드'].nunique(), 2)*100)
    return(df)
# Out:
# Train Set: (2869, 15) | Test Set: (1008, 14)

# %% [markdown]
# ## Preprocessing: NA Imputation

# %%
# '임대보증금', '임대료'의 '-'를 0으로 변환
train['임대보증금'] = train['임대보증금'].replace('-', 0).astype('float64')
train['임대료'] = train['임대료'].replace('-', 0).astype('float64')
test['임대보증금'] = test['임대보증금'].replace('-', 0).astype('float64')
test['임대료'] = test['임대료'].replace('-', 0).astype('float64')
print("'-' to 0 | "f'Train Set: {train.shape} | Test Set: {test.shape}')

# '임대보증금', '임대료' NA를 0으로 대체
train[['임대보증금', '임대료']] = train[['임대보증금', '임대료']].fillna(0)
test.loc[test['임대건물구분'] == '상가', ['임대보증금', '임대료']] = test.loc[test['임대건물구분'] == '상가', ['임대보증금', '임대료']].fillna(0)
test.loc[test['임대보증금'].isnull(), '임대보증금'] = [5787000.0, 5787000.0, 11574000.0]
test.loc[test['임대료'].isnull(), '임대료'] = [79980.0, 79980.0, 159960.0]
print('임대보증금, 임대료 | 'f'Train Set: {train.shape} | Test Set: {test.shape}')

# Test Data의 '단지코드' NA를 특정값으로 대체
test.loc[(test['단지코드'] == 'C2411') & (test['자격유형'].isnull()), '자격유형'] = 'A'
test.loc[(test['단지코드'] == 'C2253') & (test['자격유형'].isnull()), '자격유형'] = 'C'
print('Test 단지코드 NA | 'f'Test Set: {test.shape}')

# '도보 10분거리 내 지하철역 수(환승노선 수 반영)'의 NA를 0으로 대체
train['도보 10분거리 내 지하철역 수(환승노선 수 반영)'] = train['도보 10분거리 내 지하철역 수(환승노선 수 반영)'].fillna(0)
test['도보 10분거리 내 지하철역 수(환승노선 수 반영)'] = test['도보 10분거리 내 지하철역 수(환승노선 수 반영)'].fillna(0)
print('지하철 NA | 'f'Train Set: {train.shape} | Test Set: {test.shape}')
print('최종 NA 체크 | 'f'Train Set NA: {sum(train.isnull().sum())} | Test Set NA: {sum(test.isnull().sum())}')
# Out:
# '-' to 0 | Train Set: (2869, 15) | Test Set: (1008, 14)
# 임대보증금, 임대료 | Train Set: (2869, 15) | Test Set: (1008, 14)
# Test 단지코드 NA | Test Set: (1008, 14)
# 지하철 NA | Train Set: (2869, 15) | Test Set: (1008, 14)
# 최종 NA 체크 | Train Set NA: 0 | Test Set NA: 0

# %% [markdown]
# ## Preprocessing: Adding variables

# %%
## 상가수 변수 생성
store = train[train['임대건물구분'] == '상가'].groupby('단지코드', as_index=False).agg({'임대건물구분':'count'}).rename(columns={'임대건물구분':'상가수'})
train = pd.merge(train, store, how='left')
train['상가수'] = train['상가수'].fillna(0)
store = test[test['임대건물구분'] == '상가'].groupby('단지코드', as_index=False).agg({'임대건물구분':'count'}).rename(columns={'임대건물구분':'상가수'})
test = pd.merge(test, store, how='left')
test['상가수'] = test['상가수'].fillna(0)

## '전용면적별세대수합' 변수 생성
noh_by_area = train.groupby('단지코드', as_index=False).agg({'전용면적별세대수':'sum'}).rename(columns={'전용면적별세대수':'전용면적별세대수합'})
train = pd.merge(left=train, right=noh_by_area, how='left', on='단지코드')
train['전용면적별세대수합'] = train['전용면적별세대수합']-train['상가수']
noh_by_area = test.groupby('단지코드', as_index=False).agg({'전용면적별세대수':'sum'}).rename(columns={'전용면적별세대수':'전용면적별세대수합'})
test = pd.merge(left=test, right=noh_by_area, how='left', on='단지코드')
test['전용면적별세대수합'] = test['전용면적별세대수합']-test['상가수']
print('전용면적별세대수합 | 'f'Train Set: {train.shape} | Test Set: {test.shape}')

## '전용면적별세대수합_myhome' 변수 생성
train_myhome = train[train['공급유형']!='공공분양']
noh_by_area = train_myhome.groupby('단지코드', as_index=False).agg({'전용면적별세대수':'sum'}).rename(columns={'전용면적별세대수':'전용면적별세대수합_myhome'})
train = pd.merge(left=train, right=noh_by_area, how='left', on='단지코드')
train['전용면적별세대수합_myhome'] = train['전용면적별세대수합_myhome']-train['상가수']
train = train.drop('상가수', axis=1)

test_myhome = test[test['공급유형']!='공공분양']
noh_by_area = test_myhome.groupby('단지코드', as_index=False).agg({'전용면적별세대수':'sum'}).rename(columns={'전용면적별세대수':'전용면적별세대수합_myhome'})
test = pd.merge(left=test, right=noh_by_area, how='left', on='단지코드')
test['전용면적별세대수합_myhome'] = test['전용면적별세대수합_myhome']-test['상가수']
test = test.drop('상가수', axis=1)
print('전용면적별세대수합_myhome | 'f'Train Set: {train.shape} | Test Set: {test.shape}')

## '임대보증금가중평균', '임대료가중평균' 변수 생성
train['임대보증금가중평균'] = round(train['임대보증금'] * train['전용면적별세대수'] / train['전용면적별세대수합'])
rental_fee = train.groupby('단지코드', as_index=False).agg({'임대보증금가중평균':'sum'})
train = pd.merge(train, rental_fee, how='left', on='단지코드').drop(['임대보증금가중평균_x'], axis=1).rename(columns={'임대보증금가중평균_y':'임대보증금가중평균'})
train['임대료가중평균'] = round(train['임대료'] * train['전용면적별세대수'] / train['전용면적별세대수합'])
rental_fee = train.groupby('단지코드', as_index=False).agg({'임대료가중평균':'sum'})
train = pd.merge(train, rental_fee, how='left', on='단지코드').drop(['임대료가중평균_x'], axis=1).rename(columns={'임대료가중평균_y':'임대료가중평균'})
test['임대보증금가중평균'] = round(test['임대보증금'] * test['전용면적별세대수'] / test['전용면적별세대수합'])
rental_fee = test.groupby('단지코드', as_index=False).agg({'임대보증금가중평균':'sum'})
test = pd.merge(test, rental_fee, how='left', on='단지코드').drop(['임대보증금가중평균_x'], axis=1).rename(columns={'임대보증금가중평균_y':'임대보증금가중평균'})
test['임대료가중평균'] = round(test['임대료'] * test['전용면적별세대수'] / test['전용면적별세대수합'])
rental_fee = test.groupby('단지코드', as_index=False).agg({'임대료가중평균':'sum'})
test = pd.merge(test, rental_fee, how='left', on='단지코드').drop(['임대료가중평균_x'], axis=1).rename(columns={'임대료가중평균_y':'임대료가중평균'})
print('임대보증금가중평균, 임대료가중평균 | 'f'Train Set: {train.shape} | Test Set: {test.shape}')

def small_hh(df):
    df['세대구분'] = ['소형세대' if i < 40 else '기타세대' for i in df['전용면적']]
    household = df.groupby(['단지코드', '세대구분'], as_index=False).agg({'전용면적별세대수':'sum'}).pivot('단지코드', '세대구분', '전용면적별세대수').fillna(0).reset_index().drop(['기타세대'], axis=1)
    smallstore = df[df['임대건물구분']=='상가'].groupby(['단지코드', '세대구분'], as_index=False).agg({'전용면적별세대수':'sum'}).pivot('단지코드', '세대구분', '전용면적별세대수').fillna(0).reset_index().drop(['기타세대'], axis=1)
    smallstore = smallstore.rename(columns={'소형세대':'상가소형세대'})
    household = pd.merge(household[['단지코드', '소형세대']], smallstore[['단지코드', '상가소형세대']], on='단지코드', how='left').fillna(0)
    household['소형세대']= household['소형세대'] - household['상가소형세대']
    df = pd.merge(df, household[['단지코드', '소형세대']], on='단지코드', how='left').drop(['세대구분'], axis=1)
    df['소형세대'] = df['소형세대'] / df['총세대수']
    return(df)

## '소형세대' 변수 생성
train = small_hh(train)
test = small_hh(test)
print('소형세대 | 'f'Train Set: {train.shape} | Test Set: {test.shape}')

## '전용면적가중평균' 변수 생성
train['전용면적가중평균'] = round(train['전용면적'] * train['전용면적별세대수'] / train['전용면적별세대수합'])
rental_fee = train.groupby('단지코드', as_index=False).agg({'전용면적가중평균':'sum'})
train = pd.merge(train, rental_fee, how='left', on='단지코드').drop(['전용면적가중평균_x'], axis=1).rename(columns={'전용면적가중평균_y':'전용면적가중평균'})
test['전용면적가중평균'] = round(test['전용면적'] * test['전용면적별세대수'] / test['전용면적별세대수합'])
rental_fee = test.groupby('단지코드', as_index=False).agg({'전용면적가중평균':'sum'})
test = pd.merge(test, rental_fee, how='left', on='단지코드').drop(['전용면적가중평균_x'], axis=1).rename(columns={'전용면적가중평균_y':'전용면적가중평균'})
print('전용면적가중평균 | 'f'Train Set: {train.shape} | Test Set: {test.shape}')

# '차량보유인구비율' 변수 생성
age_gender_info = pd.read_csv('age_gender_info.csv')
cars = pd.DataFrame(age_gender_info.iloc[:, [7, 8, 9, 10, 12, 14]].sum(axis=1), columns=['차량보유인구비율'])
cars['지역'] = age_gender_info['지역']
train = pd.merge(train, cars, how='left', on='지역')
test = pd.merge(test, cars, how='left', on='지역')
print('차량보유인구비율 | 'f'Train Set: {train.shape} | Test Set: {test.shape}')
#30대남, 40대남녀, 50대남, 60대남

## '차량미보유세대비율' 변수 생성
noh_wo_cars = train[train['공급유형'].isin(['영구임대', '행복주택'])].groupby('단지코드', as_index=False).agg({'전용면적별세대수':'sum'}).rename(columns={'전용면적별세대수':'차량미보유세대비율'})
train = pd.merge(train, noh_wo_cars, how='left')
train['차량미보유세대비율'] = train['차량미보유세대비율'].fillna(0) / train['총세대수']
noh_wo_cars = test[test['공급유형'].isin(['영구임대', '행복주택'])].groupby('단지코드', as_index=False).agg({'전용면적별세대수':'sum'}).rename(columns={'전용면적별세대수':'차량미보유세대비율'})
test = pd.merge(test, noh_wo_cars, how='left')
test['차량미보유세대비율'] = test['차량미보유세대비율'].fillna(0) / test['총세대수']
print('차량미보유세대비율 | 'f'Train Set: {train.shape} | Test Set: {test.shape}')

## 단지명, 주소, 위도, 경도, 준공일자 생성
train = code_name(train)
train = total_member(train)
test = code_name(test)
test = total_member(test)
print('단지명, 단지명정보 | 'f'Train Set: {train.shape} | Test Set: {test.shape}')

## 준공후기간 생성
train = add_build_date(train)
test = add_build_date(test)

# '준공후기간(월)' 변수 NA값 대치 위해 '입주후기간(월)' 변수 생성 / '입주후기간(월)' 변수 생성 위해 데이터 불러오기
data.drop(['순번', '전체건수'], axis=1, inplace=True)
data['전용면적'] = np.round(data['전용면적'], 2)
data = data.rename(columns={'단지명': '단지명2'})
data['지역'] = ['세종특별자치시' if i[0] == '세종시' else i[0] for i in data['지역'].str.split()]
noh_by_area = data.groupby('단지명2', as_index=False).agg({'전용면적별세대수':'sum'})
noh_by_area.columns = ['단지명2', '전용면적별세대수합']
data = pd.merge(left=data, right=noh_by_area, how='left', on='단지명2')
data.drop(['총세대수'], axis=1, inplace=True)
in_date = data[['단지명2', '최초입주년월']].drop_duplicates().reset_index(drop=True)
in_date.loc[(in_date['최초입주년월']<198001)|(in_date['최초입주년월']>=202107),'최초입주년월']=np.nan
in_date.loc[in_date['최초입주년월'].notnull(), '년'] = in_date.loc[in_date['최초입주년월'].notnull(), '최초입주년월'] //100
in_date.loc[in_date['최초입주년월'].notnull(), '월'] = in_date.loc[in_date['최초입주년월'].notnull(), '최초입주년월'] % 100
in_date.loc[in_date['최초입주년월'].notnull(), '입주후기간(월)'] = 2021*12+ 7 - (in_date.loc[in_date['최초입주년월'].notnull(), '년']*12 + in_date.loc[in_date['최초입주년월'].notnull(), '월'])
in_date = in_date.drop(['최초입주년월', '년', '월'], axis=1)
in_date['입주후기간(월)'] = in_date['입주후기간(월)'].astype('float64')
data = pd.merge(data, in_date, how='left', on='단지명2')

# 입주후기간 생성
train = add_in_date(train)
test = add_in_date(test)

# 준공후기간(월)의 NA값들 입주후기간(월)로 imputation 후 필요없는 column들 제거
train.loc[(train['준공후기간(월)'].isnull())&(train['입주후기간(월)'].notnull()), '준공후기간(월)']= train.loc[(train['준공후기간(월)'].isnull())&(train['입주후기간(월)'].notnull()), '입주후기간(월)']
test.loc[(test['준공후기간(월)'].isnull())&(test['입주후기간(월)'].notnull()), '준공후기간(월)']= test.loc[(test['준공후기간(월)'].isnull())&(test['입주후기간(월)'].notnull()), '입주후기간(월)']
train = train.drop(['단지명2', '입주후기간(월)'], axis=1)
test = test.drop(['단지명2', '입주후기간(월)'], axis=1)

print('준공후기간 | 'f'Train Set: {train.shape} | Test Set: {test.shape}')
# Out:
# 전용면적별세대수합 | Train Set: (2869, 17) | Test Set: (1008, 16)
# 전용면적별세대수합_myhome | Train Set: (2869, 17) | Test Set: (1008, 16)
# 임대보증금가중평균, 임대료가중평균 | Train Set: (2869, 19) | Test Set: (1008, 18)
# 소형세대 | Train Set: (2869, 20) | Test Set: (1008, 19)
# 전용면적가중평균 | Train Set: (2869, 21) | Test Set: (1008, 20)
# 차량보유인구비율 | Train Set: (2869, 22) | Test Set: (1008, 21)
# 차량미보유세대비율 | Train Set: (2869, 23) | Test Set: (1008, 22)
# 53
# 393
# 394
# 397
# 398
# 399
# 400
# 401
# 403
# 404
# 405
# 406
# 408
# 139
# 141
# 142
# 143
# 144
# 145
# 146
# 단지명, 단지명정보 | Train Set: (2883, 28) | Test Set: (1008, 27)
# 준공후기간 | Train Set: (2883, 28) | Test Set: (1008, 27)

# %% [markdown]
# ## Preprocessing: Categorical data encoding

# %%
## One-hot encoding
train.loc[train.공급유형.isin(['공공임대(5년)', '공공분양', '공공임대(10년)', '공공임대(분납)']), '공급유형'] = '공공임대(5년/10년/분납/분양)'
train.loc[train.공급유형.isin(['장기전세', '국민임대']), '공급유형'] = '국민임대/장기전세'
train.loc[train.자격유형.isin(['J', 'L', 'K', 'N', 'M', 'O']), '자격유형'] = '행복주택_공급대상'
train.loc[train.자격유형.isin(['H', 'B', 'E', 'G']), '자격유형'] = '국민임대/장기전세_공급대상'
train.loc[train.자격유형.isin(['C', 'I', 'F']), '자격유형'] = '영구임대_공급대상'

test.loc[test.공급유형.isin(['공공임대(5년)', '공공분양', '공공임대(10년)', '공공임대(분납)']), '공급유형'] = '공공임대(5년/10년/분납/분양)'
test.loc[test.공급유형.isin(['장기전세', '국민임대']), '공급유형'] = '국민임대/장기전세'
test.loc[test.자격유형.isin(['J', 'L', 'K', 'N', 'M', 'O']), '자격유형'] = '행복주택_공급대상'
test.loc[test.자격유형.isin(['H', 'B', 'E', 'G']), '자격유형'] = '국민임대/장기전세_공급대상'
test.loc[test.자격유형.isin(['C', 'I', 'F']), '자격유형'] = '영구임대_공급대상'

supply_type = train.groupby(['단지코드', '공급유형'], as_index=False).agg({'전용면적별세대수':'sum'}).pivot('단지코드', '공급유형', '전용면적별세대수').fillna(0).reset_index()
supply_type.set_index('단지코드', inplace=True)
supply_type[(supply_type != 0)] = 1
supply_type.reset_index(inplace=True)

qual_type = train.groupby(['단지코드', '자격유형'], as_index=False).agg({'전용면적별세대수':'sum'}).pivot('단지코드', '자격유형', '전용면적별세대수').fillna(0).reset_index()
qual_type.set_index('단지코드', inplace=True)
qual_type[(qual_type != 0)] = 1
qual_type.reset_index(inplace=True)

build_type = train.groupby(['단지코드', '임대건물구분'], as_index=False).agg({'전용면적별세대수':'sum'}).pivot('단지코드', '임대건물구분', '전용면적별세대수').fillna(0).reset_index()
build_type.set_index('단지코드', inplace=True)
build_type[(build_type != 0)] = 1
build_type.reset_index(inplace=True)

train = pd.merge(train, supply_type, how='left')
train = pd.merge(train, qual_type, how='left')
train = pd.merge(train, build_type, how='left')
train = train.rename(columns={'A':'자격유형_A', 'D':'자격유형_D'})

supply_type = test.groupby(['단지코드', '공급유형'], as_index=False).agg({'전용면적별세대수':'sum'}).pivot('단지코드', '공급유형', '전용면적별세대수').fillna(0).reset_index()
supply_type.set_index('단지코드', inplace=True)
supply_type[(supply_type != 0)] = 1
supply_type.reset_index(inplace=True)

qual_type = test.groupby(['단지코드', '자격유형'], as_index=False).agg({'전용면적별세대수':'sum'}).pivot('단지코드', '자격유형', '전용면적별세대수').fillna(0).reset_index()
qual_type.set_index('단지코드', inplace=True)
qual_type[(qual_type != 0)] = 1
qual_type.reset_index(inplace=True)

build_type = test.groupby(['단지코드', '임대건물구분'], as_index=False).agg({'전용면적별세대수':'sum'}).pivot('단지코드', '임대건물구분', '전용면적별세대수').fillna(0).reset_index()
build_type.set_index('단지코드', inplace=True)
build_type[(build_type != 0)] = 1
build_type.reset_index(inplace=True)

test = pd.merge(test, supply_type, how='left')
test = pd.merge(test, qual_type, how='left')
test = pd.merge(test, build_type, how='left')
test = test.rename(columns={'A':'자격유형_A', 'D':'자격유형_D'})

print(f'Train Set: {train.shape} | Test Set: {test.shape}')

X_train, X_test = train.set_index('단지코드'), test.set_index('단지코드')
X_train, X_test = X_train.drop(columns = ['아파트']), X_test.drop(columns = ['아파트'])
X_train, X_test = X_train[X_train['도보 10분거리 내 지하철역 수(환승노선 수 반영)'] != 3], X_test[X_test['도보 10분거리 내 지하철역 수(환승노선 수 반영)'] != 3]
print(f'X_Train Set: {X_train.shape} | X_Test Set: {X_test.shape}')
# Out:
# Train Set: (2883, 41) | Test Set: (1008, 40)
# X_Train Set: (2877, 39) | X_Test Set: (1008, 38)

# %%
save_X_train = X_train.copy()
save_X_test = X_test.copy()

# %%
X_train = save_X_train.copy()
X_test = save_X_test.copy()

# %% [markdown]
# ## Preprocessing: Selecting unique variables

# %%
features = ['총세대수', '공가수', '도보 10분거리 내 버스정류장 수', '단지내주차면수', # 기존변수
'전용면적가중평균', '차량미보유세대비율', '소형세대', '임대료가중평균','차량보유인구비율', '준공후기간(월)',# 새 변수
'자격유형_A','자격유형_D','국민임대/장기전세_공급대상','국민임대/장기전세','행복주택_공급대상','영구임대_공급대상', #자격유형
'지역', '도보 10분거리 내 지하철역 수(환승노선 수 반영)', #Target encoding is needed
'공공임대(5년/10년/분납/분양)','공공임대(50년)','행복주택','영구임대','임대상가','상가']

X_train = X_train[features + ['총입주민수']].drop_duplicates()
X_test = X_test[features].drop_duplicates()

# %% [markdown]
# ## Preprocessing: After drop_duplicates())

# %%
## Target encoding
encoding_features = ['지역', '도보 10분거리 내 지하철역 수(환승노선 수 반영)']
for f in encoding_features:
    mapping = X_train.groupby([f])['총입주민수'].agg(['mean','median','std'])
    mapping_values = []
    for l in X_train[f].values:
        mapping_values.extend([mapping.loc[l].values])
    bincount = pd.DataFrame(mapping_values, columns = [f+'_mean', f+'_median', f+'_std', ], index = X_train.index)
    X_train = pd.concat([X_train,bincount], axis= 1).drop(columns = [f])

    mapping_values = []
    for l in X_test[f].values:
        mapping_values.extend([mapping.loc[l].values])
    bincount = pd.DataFrame(mapping_values, columns = [f+'_mean', f+'_median', f+'_std', ], index = X_test.index)
    X_test = pd.concat([X_test,bincount], axis= 1).drop(columns = [f])

# 도보 10분거리 std는 그림상 의미가 없기에 Drop
X_train = X_train.iloc[:,:-2]
X_test = X_test.iloc[:,:-2]
print(f'X_Train Set: {X_train.shape} | X_Test Set: {X_test.shape}')
# Out:
# X_Train Set: (410, 27) | X_Test Set: (147, 26)

# %%
# '준공후기간(월)' Imputation
def date_impute(df):
    df['준공후기간(월)']=df['준공후기간(월)'].astype('float64')
    df_num = df.loc[:,df.dtypes!=object]
    df_imp = mice(df_num.values)
    df_imp = pd.DataFrame(df_imp)
    df_imp.columns = df_num.columns
    df_imp.index = df.index
    df['준공후기간(월)'] = df_imp['준공후기간(월)']
    return(df)

X_train = date_impute(X_train)
X_test = date_impute(X_test)

# %% [markdown]
# ## Preprocessing: Scaling

# %%
## 지역: Robust Scaling
scaler = RobustScaler()
loc_f = ['지역_mean', '지역_median', '지역_std']
X_train.loc[:, loc_f] = scaler.fit_transform(X_train[loc_f])
X_test.loc[:, loc_f] = scaler.transform(X_test[loc_f])

# 나머지 Scaling
scaling_features = ['총세대수',
                     '공가수',
                     '도보 10분거리 내 버스정류장 수',
                     '단지내주차면수', 
                     '차량보유인구비율', '전용면적가중평균', '차량미보유세대비율', '소형세대', 
                     '임대료가중평균', '준공후기간(월)',
                     '지역_mean',
                     '지역_median',
                     '지역_std', 
                     '도보 10분거리 내 지하철역 수(환승노선 수 반영)_mean']
scaler = StandardScaler()
X_train.loc[:, scaling_features] = scaler.fit_transform(X_train[scaling_features])
X_test.loc[:, scaling_features] = scaler.transform(X_test[scaling_features])

X = X_train.drop(columns = ['총입주민수'])
y = X_train['총입주민수']

# %% [markdown]
# ## Modeling(1): Cat Boost

# %%
def objective(trial: Trial) -> float:
    params_cat = {
        "random_state": 42,
        "learning_rate": 0.05,
        "n_estimators": 10000,
        "verbose" : 1,
        "objective" : "MAE",
        "max_depth": trial.suggest_int("max_depth", 1, 16),
        "colsample_bylevel": trial.suggest_float("colsample_bylevel", 0.8, 1.0),
        "subsample": trial.suggest_float("subsample", 0.3, 1.0),
        "min_child_samples": trial.suggest_int("min_child_samples", 5, 100),
        "max_bin": trial.suggest_int("max_bin", 200, 500),
    }
    
    X_tr, X_val, y_tr, y_val = train_test_split(X, y, test_size=0.2)

    model = CatBoostRegressor(**params_cat)
    model.fit(
        X_tr,
        y_tr,
        eval_set=[(X_tr, y_tr), (X_val, y_val)],
        early_stopping_rounds=10,
        verbose=False,
    )

    cat_pred = model.predict(X_val)
    log_score = mean_absolute_error(y_val, cat_pred)
    
    return log_score

# %% [markdown]
# ## Modeling(1): Hyper-parameter tuning

# %%
sampler = TPESampler(seed=40)
study = optuna.create_study(
    study_name="cat_opt",
    direction="minimize",
    sampler=sampler,
)
study.optimize(objective, n_trials=10)
print("Best Score:", study.best_value)
print("Best trial:", study.best_trial.params)
# Out:
# [I 2021-07-29 22:49:16,691] A new study created in memory with name: cat_opt
# [I 2021-07-29 22:49:18,537] Trial 0 finished with value: 114.00474495548279 and parameters: {'max_depth': 7, 'colsample_bylevel': 0.811073208022372, 'subsample': 0.8519744142407268, 'min_child_samples': 32, 'max_bin': 335}. Best is trial 0 with value: 114.00474495548279.
# [I 2021-07-29 22:49:19,188] Trial 1 finished with value: 97.56009934656772 and parameters: {'max_depth': 5, 'colsample_bylevel': 0.9052799048594291, 'subsample': 0.7366685490192806, 'min_child_samples': 79, 'max_bin': 406}. Best is trial 1 with value: 97.56009934656772.
# [I 2021-07-29 22:57:18,370] Trial 2 finished with value: 119.05733431150519 and parameters: {'max_depth': 16, 'colsample_bylevel': 0.9201632184431826, 'subsample': 0.8697779639600969, 'min_child_samples': 73, 'max_bin': 208}. Best is trial 1 with value: 97.56009934656772.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/5s/v5yqb7hs1vzf2rg6qgkmvky00000gn/T/ipykernel_4089/1111713698.py in <module>
#       5     sampler=sampler,
#       6 )
# ----> 7 study.optimize(objective, n_trials=10)
#       8 print("Best Score:", study.best_value)
#       9 print("Best trial:", study.best_trial.params)
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/study.py in optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     399             )
#     400
# --> 401         _optimize(
#     402             study=self,
#     403             func=func,
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/_optimize.py in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      63     try:
#      64         if n_jobs == 1:
# ---> 65             _optimize_sequential(
#      66                 study,
#      67                 func,
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/_optimize.py in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     160
#     161         try:
# --> 162             trial = _run_trial(study, func, catch)
#     163         except Exception:
#     164             raise
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/_optimize.py in _run_trial(study, func, catch)
#     214
#     215     try:
# --> 216         value_or_values = func(trial)
#     217     except exceptions.TrialPruned as e:
#     218         # TODO(mamu): Handle multi-objective cases.
#
# /var/folders/5s/v5yqb7hs1vzf2rg6qgkmvky00000gn/T/ipykernel_4089/4003920013.py in objective(trial)
#      16
#      17     model = CatBoostRegressor(**params_cat)
# ---> 18     model.fit(
#      19         X_tr,
#      20         y_tr,
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/catboost/core.py in fit(self, X, y, cat_features, sample_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    5254             CatBoostRegressor._check_is_compatible_loss(params['loss_function'])
#    5255
# -> 5256         return self._fit(X, y, cat_features, None, None, None, sample_weight, None, None, None, None, baseline,
#    5257                          use_best_model, eval_set, verbose, logging_level, plot, column_description,
#    5258                          verbose_eval, metric_period, silent, early_stopping_rounds,
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/catboost/core.py in _fit(self, X, y, cat_features, text_features, embedding_features, pairs, sample_weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    1992         with log_fixup(log_cout, log_cerr), \
#    1993             plot_wrapper(plot, [_get_train_dir(self.get_params())]):
# -> 1994             self._train(
#    1995                 train_pool,
#    1996                 train_params["eval_sets"],
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/catboost/core.py in _train(self, train_pool, test_pool, params, allow_clear_pool, init_model)
#    1423
#    1424     def _train(self, train_pool, test_pool, params, allow_clear_pool, init_model):
# -> 1425         self._object._train(train_pool, test_pool, params, allow_clear_pool, init_model._object if init_model else None)
#    1426         self._set_trained_model_attributes()
#    1427
#
# _catboost.pyx in _catboost._CatBoost._train()
#
# _catboost.pyx in _catboost._CatBoost._train()
#
# KeyboardInterrupt:

# %%
cat_p ={'max_depth': 3, 'colsample_bylevel': 0.8608484485919076, 'subsample': 0.6673295021425665, 'min_child_samples': 46, 'max_bin': 287}
cat = CatBoostRegressor(**cat_p)
cat.fit(X, y, verbose = 0)
pred = cat.predict(X_test)
train_pool = Pool(X, y)
data = pd.DataFrame({'feature_importance': cat.get_feature_importance(train_pool), 
              'feature_names': X.columns}).sort_values(by=['feature_importance'], 
                                                       ascending=False)
# Out:
# Custom logger is already specified. Specify more than one logger at same time is not thread safe.

# %%
## 최종
kfold = KFold(n_splits=10, shuffle=True, random_state=10)
score = cross_val_score(cat, X, y, cv=kfold, scoring='neg_mean_absolute_error')
print(f'평균: {-score.mean()} | 표준편차: {score.std()}')

# 고령인구비율, 세대당가구원: 평균: 114.43259187398844 | 표준편차: 14.893129935277042
# 기본: 평균: 112.04591699230187 | 표준편차: 15.662175580231859
# 평균: 118.80416096690533 | 표준편차: 17.015570107182704
# 차량보유인구비율 변경 평균: 113.48924860821083 | 표준편차: 13.671311871122764
# Out:
# 평균: 177.24851824516023 | 표준편차: 27.783636156529155

# %% [markdown]
# ## Modeling(2): CatBoost

# %%
X_train = save_X_train.copy()
X_test = save_X_test.copy()

features = ['총세대수', '공가수', '도보 10분거리 내 버스정류장 수', '단지내주차면수', '총입주민수', # 기존변수
'전용면적가중평균', '차량미보유세대비율', '소형세대', '임대료가중평균','차량보유인구비율', '준공후기간(월)',# 새 변수
'자격유형_A','자격유형_D','국민임대/장기전세_공급대상','국민임대/장기전세','행복주택_공급대상','영구임대_공급대상', #자격유형
'지역', '도보 10분거리 내 지하철역 수(환승노선 수 반영)', #Target encoding is needed
'공공임대(5년/10년/분납/분양)','공공임대(50년)','행복주택','영구임대','임대상가','상가']

X_train = X_train[features + ['등록차량수']].drop_duplicates()
X_test = X_test[features].drop_duplicates()
X_test['총입주민수'] = pred

## Target encoding
encoding_features = ['지역', '도보 10분거리 내 지하철역 수(환승노선 수 반영)']
for f in encoding_features:
    mapping = X_train.groupby([f])['등록차량수'].agg(['mean','median','std'])
    mapping_values = []
    for l in X_train[f].values:
        mapping_values.extend([mapping.loc[l].values])
    bincount = pd.DataFrame(mapping_values, columns = [f+'_mean', f+'_median', f+'_std', ], index = X_train.index)
    X_train = pd.concat([X_train,bincount], axis= 1).drop(columns = [f])

    mapping_values = []
    for l in X_test[f].values:
        mapping_values.extend([mapping.loc[l].values])
    bincount = pd.DataFrame(mapping_values, columns = [f+'_mean', f+'_median', f+'_std', ], index = X_test.index)
    X_test = pd.concat([X_test,bincount], axis= 1).drop(columns = [f])

# 도보 10분거리 std는 그림상 의미가 없기에 Drop
X_train = X_train.iloc[:,:-2]
X_test = X_test.iloc[:,:-2]
print(f'X_Train Set: {X_train.shape} | X_Test Set: {X_test.shape}')

# '준공후기간(월)' Imputation
def date_impute(df):
    df['준공후기간(월)']=df['준공후기간(월)'].astype('float64')
    df_num = df.loc[:,df.dtypes!=object]
    df_imp = mice(df_num.values)
    df_imp = pd.DataFrame(df_imp)
    df_imp.columns = df_num.columns
    df_imp.index = df.index
    df['준공후기간(월)'] = df_imp['준공후기간(월)']
    return(df)

X_train = date_impute(X_train)
X_test = date_impute(X_test)
## 지역: Robust Scaling
scaler = RobustScaler()
loc_f = ['지역_mean', '지역_median', '지역_std']
X_train.loc[:, loc_f] = scaler.fit_transform(X_train[loc_f])
X_test.loc[:, loc_f] = scaler.transform(X_test[loc_f])

# 나머지 Scaling
scaling_features = ['총세대수',
                     '공가수',
                     '도보 10분거리 내 버스정류장 수',
                     '단지내주차면수', '총입주민수',
                     '차량보유인구비율', '전용면적가중평균', '차량미보유세대비율', '소형세대', 
                     '임대료가중평균', '준공후기간(월)',
                     '지역_mean',
                     '지역_median',
                     '지역_std', 
                     '도보 10분거리 내 지하철역 수(환승노선 수 반영)_mean']

scaler = StandardScaler()
X_train.loc[:, scaling_features] = scaler.fit_transform(X_train[scaling_features])
X_test.loc[:, scaling_features] = scaler.transform(X_test[scaling_features])

X = X_train.drop(columns = ['등록차량수'])
y = X_train['등록차량수']
# Out:
# X_Train Set: (410, 27) | X_Test Set: (147, 26)

# %%
cat_p ={'max_depth': 3, 'colsample_bylevel': 0.8608484485919076, 'subsample': 0.6673295021425665, 'min_child_samples': 46, 'max_bin': 287}
cat2 = CatBoostRegressor(**cat_p)
cat2.fit(X, y, verbose = 0)
pred2 = cat2.predict(X_test)

# %% [markdown]
# best private score냈던 모델 cv score: 평균: 112.39400848306896 | 표준편차: 14.537099748891821

# %%
## 최종
kfold = KFold(n_splits=10, shuffle=True, random_state=10)
score = cross_val_score(cat2, X, y, cv=kfold, scoring='neg_mean_absolute_error')
print(f'평균: {-score.mean()} | 표준편차: {score.std()}')
# 고령인구비율, 세대당가구원: 평균: 114.43259187398844 | 표준편차: 14.893129935277042
# 기본: 평균: 112.04591699230187 | 표준편차: 15.662175580231859
# 평균: 118.80416096690533 | 표준편차: 17.015570107182704
# 차량보유인구비율 변경 평균: 113.48924860821083 | 표준편차: 13.671311871122764
# 평균: 112.91943764176008 | 표준편차: 14.79204947165533
# Out:
#  1.4s	remaining: 843ms
# 624:	learn: 92.8940144	total: 1.4s	remaining: 840ms
# 625:	learn: 92.8200808	total: 1.4s	remaining: 838ms
# 626:	learn: 92.7508113	total: 1.41s	remaining: 839ms
# 627:	learn: 92.6918062	total: 1.41s	remaining: 836ms
# 628:	learn: 92.5485719	total: 1.41s	remaining: 833ms
# 629:	learn: 92.5260889	total: 1.41s	remaining: 829ms
# 630:	learn: 92.4449822	total: 1.41s	remaining: 826ms
# 631:	learn: 92.3654786	total: 1.41s	remaining: 823ms
# 632:	learn: 92.3545528	total: 1.41s	remaining: 820ms
# 633:	learn: 92.3463066	total: 1.42s	remaining: 821ms
# 634:	learn: 92.2536085	total: 1.42s	remaining: 818ms
# 635:	learn: 92.1546940	total: 1.42s	remaining: 814ms
# 636:	learn: 92.1460320	total: 1.42s	remaining: 811ms
# 637:	learn: 92.0940472	total: 1.42s	remaining: 808ms
# 638:	learn: 92.0363144	total: 1.43s	remaining: 805ms
# 639:	learn: 92.0279742	total: 1.43s	remaining: 802ms
# 640:	learn: 91.9522719	total: 1.43s	remaining: 800ms
# 641:	learn: 91.8429693	total: 1.43s	remaining: 797ms
# 642:	learn: 91.8213689	total: 1.43s	remaining: 797ms
# 643:	learn: 91.7909343	total: 1.44s	remaining: 794ms
# 644:	learn: 91.7399164	total: 1.44s	remaining: 792ms
# 645:	learn: 91.6206014	total: 1.44s	remaining: 789ms
# 646:	learn: 91.5327973	total: 1.44s	remaining: 786ms
# 647:	learn: 91.5017064	total: 1.44s	remaining: 783ms
# 648:	learn: 91.4900981	total: 1.44s	remaining: 780ms
# 649:	learn: 91.3677663	total: 1.44s	remaining: 777ms
# 650:	learn: 91.2257737	total: 1.44s	remaining: 774ms
# 651:	learn: 91.1476270	total: 1.44s	remaining: 771ms
# 652:	learn: 91.0384255	total: 1.45s	remaining: 770ms
# 653:	learn: 90.9674872	total: 1.45s	remaining: 767ms
# 654:	learn: 90.9435906	total: 1.45s	remaining: 764ms
# 655:	learn: 90.8746588	total: 1.45s	remaining: 761ms
# 656:	learn: 90.7753012	total: 1.45s	remaining: 758ms
# 657:	learn: 90.7138143	total: 1.45s	remaining: 756ms
# 658:	learn: 90.6478520	total: 1.45s	remaining: 753ms
# 659:	learn: 90.5921625	total: 1.46s	remaining: 750ms
# 660:	learn: 90.5491687	total: 1.46s	remaining: 747ms
# 661:	learn: 90.4680467	total: 1.46s	remaining: 744ms
# 662:	learn: 90.3461452	total: 1.46s	remaining: 741ms
# 663:	learn: 90.2801687	total: 1.46s	remaining: 741ms
# 664:	learn: 90.2098810	total: 1.47s	remaining: 738ms
# 665:	learn: 90.1660620	total: 1.47s	remaining: 735ms
# 666:	learn: 90.1135175	total: 1.47s	remaining: 732ms
# 667:	learn: 90.0770492	total: 1.47s	remaining: 729ms
# 668:	learn: 90.0691311	total: 1.47s	remaining: 726ms
# 669:	learn: 90.0170087	total: 1.47s	remaining: 724ms
# 670:	learn: 89.9768095	total: 1.47s	remaining: 721ms
# 671:	learn: 89.9236603	total: 1.47s	remaining: 718ms
# 672:	learn: 89.8607330	total: 1.47s	remaining: 715ms
# 673:	learn: 89.8513682	total: 1.47s	remaining: 712ms
# 674:	learn: 89.8019183	total: 1.48s	remaining: 711ms
# 675:	learn: 89.6611600	total: 1.48s	remaining: 708ms
# 676:	learn: 89.5960194	total: 1.48s	remaining: 705ms
# 677:	learn: 89.5869788	total: 1.48s	remaining: 702ms
# 678:	learn: 89.4868229	total: 1.48s	remaining: 699ms
# 679:	learn: 89.4416239	total: 1.48s	remaining: 697ms
# 680:	learn: 89.3921570	total: 1.48s	remaining: 694ms
# 681:	learn: 89.3830379	total: 1.48s	remaining: 691ms
# 682:	learn: 89.3754687	total: 1.48s	remaining: 688ms
# 683:	learn: 89.2773168	total: 1.48s	remaining: 685ms
# 684:	learn: 89.2141891	total: 1.48s	remaining: 682ms
# 685:	learn: 89.0866981	total: 1.5s	remaining: 687ms
# 686:	learn: 89.0115028	total: 1.5s	remaining: 685ms
# 687:	learn: 88.9212327	total: 1.5s	remaining: 682ms
# 688:	learn: 88.9125862	total: 1.51s	remaining: 681ms
# 689:	learn: 88.8691450	total: 1.51s	remaining: 678ms
# 690:	learn: 88.7884589	total: 1.51s	remaining: 675ms
# 691:	learn: 88.7806499	total: 1.51s	remaining: 673ms
# 692:	learn: 88.6670476	total: 1.51s	remaining: 670ms
# 693:	learn: 88.5874421	total: 1.51s	remaining: 667ms
# 694:	learn: 88.5029146	total: 1.51s	remaining: 664ms
# 695:	learn: 88.4631839	total: 1.51s	remaining: 661ms
# 696:	learn: 88.4272094	total: 1.51s	remaining: 658ms
# 697:	learn: 88.4196706	total: 1.51s	remaining: 656ms
# 698:	learn: 88.3790066	total: 1.52s	remaining: 653ms
# 699:	learn: 88.2871438	total: 1.52s	remaining: 650ms
# 700:	learn: 88.2637879	total: 1.52s	remaining: 648ms
# 701:	learn: 88.2455290	total: 1.52s	remaining: 645ms
# 702:	learn: 88.0690340	total: 1.52s	remaining: 643ms
# 703:	learn: 87.9632657	total: 1.52s	remaining: 640ms
# 704:	learn: 87.8827881	total: 1.52s	remaining: 637ms
# 705:	learn: 87.8110470	total: 1.52s	remaining: 635ms
# 706:	learn: 87.8031287	total: 1.53s	remaining: 633ms
# 707:	learn: 87.7176173	total: 1.53s	remaining: 630ms
# 708:	learn: 87.6957320	total: 1.53s	remaining: 628ms
# 709:	learn: 87.6404099	total: 1.53s	remaining: 626ms
# 710:	learn: 87.5565698	total: 1.53s	remaining: 623ms
# 711:	learn: 87.5004813	total: 1.53s	remaining: 620ms
# 712:	learn: 87.4483621	total: 1.53s	remaining: 618ms
# 713:	learn: 87.3362940	total: 1.53s	remaining: 615ms
# 714:	learn: 87.2432548	total: 1.53s	remaining: 612ms
# 715:	learn: 87.2214168	total: 1.54s	remaining: 609ms
# 716:	learn: 87.1955285	total: 1.54s	remaining: 607ms
# 717:	learn: 87.1469485	total: 1.54s	remaining: 604ms
# 718:	learn: 87.0209426	total: 1.54s	remaining: 602ms
# 719:	learn: 86.9631997	total: 1.54s	remaining: 599ms
# 720:	learn: 86.9556615	total: 1.54s	remaining: 596ms
# 721:	learn: 86.9464916	total: 1.54s	remaining: 594ms
# 722:	learn: 86.8431088	total: 1.54s	remaining: 591ms
# 723:	learn: 86.7817127	total: 1.57s	remaining: 600ms
# 724:	learn: 86.7721775	total: 1.58s	remaining: 598ms
# 725:	learn: 86.6660135	total: 1.58s	remaining: 597ms
# 726:	learn: 86.5967024	total: 1.58s	remaining: 594ms
# 727:	learn: 86.4754490	total: 1.58s	remaining: 591ms
# 728:	learn: 86.3882193	total: 1.58s	remaining: 589ms
# 729:	learn: 86.3042128	total: 1.59s	remaining: 587ms
# 730:	learn: 86.2226202	total: 1.59s	remaining: 585ms
# 731:	learn: 86.1848259	total: 1.59s	remaining: 582ms
# 732:	learn: 86.0923922	total: 1.59s	remaining: 580ms
# 733:	learn: 86.0854215	total: 1.6s	remaining: 581ms
# 734:	learn: 85.9962605	total: 1.61s	remaining: 581ms
# 735:	learn: 85.9136958	total: 1.61s	remaining: 578ms
# 736:	learn: 85.9055964	total: 1.61s	remaining: 575ms
# 737:	learn: 85.8606649	total: 1.61s	remaining: 573ms
# 738:	learn: 85.8054774	total: 1.63s	remaining: 575ms
# 739:	learn: 85.7680770	total: 1.66s	remaining: 583ms
# 740:	learn: 85.6865215	total: 1.66s	remaining: 580ms
# 741:	learn: 85.6074729	total: 1.66s	remaining: 579ms
# 742:	learn: 85.5235016	total: 1.66s	remaining: 576ms
# 743:	learn: 85.4764407	total: 1.67s	remaining: 573ms
# 744:	learn: 85.4165903	total: 1.67s	remaining: 570ms
# 745:	learn: 85.3513008	total: 1.67s	remaining: 568ms
# 746:	learn: 85.3072659	total: 1.67s	remaining: 566ms
# 747:	learn: 85.3004886	total: 1.67s	remaining: 563ms
# 748:	learn: 85.2808410	total: 1.67s	remaining: 561ms
# 749:	learn: 85.2720575	total: 1.67s	remaining: 558ms
# 750:	learn: 85.2350293	total: 1.68s	remaining: 555ms
# 751:	learn: 85.2294615	total: 1.68s	remaining: 553ms
# 752:	learn: 85.1670808	total: 1.68s	remaining: 550ms
# 753:	learn: 85.1189855	total: 1.68s	remaining: 547ms
# 754:	learn: 85.0336479	total: 1.68s	remaining: 545ms
# 755:	learn: 84.9903757	total: 1.68s	remaining: 542ms
# 756:	learn: 84.9828751	total: 1.68s	remaining: 539ms
# 757:	learn: 84.8905317	total: 1.68s	remaining: 537ms
# 758:	learn: 84.7851570	total: 1.69s	remaining: 536ms
# 759:	learn: 84.7019751	total: 1.69s	remaining: 533ms
# 760:	learn: 84.6386106	total: 1.69s	remaining: 531ms
# 761:	learn: 84.5631830	total: 1.69s	remaining: 528ms
# 762:	learn: 84.5229386	total: 1.69s	remaining: 526ms
# 763:	learn: 84.4295334	total: 1.69s	remaining: 523ms
# 764:	learn: 84.4236030	total: 1.69s	remaining: 520ms
# 765:	learn: 84.3946946	total: 1.69s	remaining: 518ms
# 766:	learn: 84.3175858	total: 1.69s	remaining: 515ms
# 767:	learn: 84.2790510	total: 1.7s	remaining: 512ms
# 768:	learn: 84.1871477	total: 1.7s	remaining: 510ms
# 769:	learn: 84.0823637	total: 1.7s	remaining: 507ms
# 770:	learn: 84.0508753	total: 1.7s	remaining: 505ms
# 771:	learn: 83.9769611	total: 1.7s	remaining: 502ms
# 772:	learn: 83.9640569	total: 1.7s	remaining: 500ms
# 773:	learn: 83.9489505	total: 1.7s	remaining: 497ms
# 774:	learn: 83.9128150	total: 1.7s	remaining: 495ms
# 775:	learn: 83.8108732	total: 1.7s	remaining: 492ms
# 776:	learn: 83.7590376	total: 1.7s	remaining: 489ms
# 777:	learn: 83.7241786	total: 1.71s	remaining: 487ms
# 778:	learn: 83.6646863	total: 1.71s	remaining: 484ms
# 779:	learn: 83.6284158	total: 1.71s	remaining: 481ms
# 780:	learn: 83.5620318	total: 1.71s	remaining: 479ms
# 781:	learn: 83.5562861	total: 1.71s	remaining: 476ms
# 782:	learn: 83.5170315	total: 1.71s	remaining: 474ms
# 783:	learn: 83.4853387	total: 1.71s	remaining: 471ms
# 784:	learn: 83.4803797	total: 1.71s	remaining: 469ms
# 785:	learn: 83.4661866	total: 1.71s	remaining: 467ms
# 786:	learn: 83.4498295	total: 1.72s	remaining: 464ms
# 787:	learn: 83.4030766	total: 1.72s	remaining: 462ms
# 788:	learn: 83.3879118	total: 1.72s	remaining: 459ms
# 789:	learn: 83.3420921	total: 1.72s	remaining: 457ms
# 790:	learn: 83.3225625	total: 1.72s	remaining: 454ms
# 791:	learn: 83.3162423	total: 1.72s	remaining: 452ms
# 792:	learn: 83.2356897	total: 1.72s	remaining: 449ms
# 793:	learn: 83.1893486	total: 1.72s	remaining: 446ms
# 794:	learn: 83.1852320	total: 1.72s	remaining: 444ms
# 795:	learn: 83.1050518	total: 1.72s	remaining: 441ms
# 796:	learn: 83.0285158	total: 1.72s	remaining: 439ms
# 797:	learn: 82.9945121	total: 1.72s	remaining: 436ms
# 798:	learn: 82.9657878	total: 1.73s	remaining: 434ms
# 799:	learn: 82.9062964	total: 1.73s	remaining: 432ms
# 800:	learn: 82.8334121	total: 1.73s	remaining: 429ms
# 801:	learn: 82.8279975	total: 1.73s	remaining: 427ms
# 802:	learn: 82.7380621	total: 1.73s	remaining: 424ms
# 803:	learn: 82.6610898	total: 1.73s	remaining: 422ms
# 804:	learn: 82.6034114	total: 1.73s	remaining: 419ms
# 805:	learn: 82.5479952	total: 1.73s	remaining: 417ms
# 806:	learn: 82.5400408	total: 1.73s	remaining: 414ms
# 807:	learn: 82.4725297	total: 1.73s	remaining: 412ms
# 808:	learn: 82.4683329	total: 1.73s	remaining: 409ms
# 809:	learn: 82.4213953	total: 1.73s	remaining: 407ms
# 810:	learn: 82.3950388	total: 1.74s	remaining: 404ms
# 811:	learn: 82.3857858	total: 1.74s	remaining: 402ms
# 812:	learn: 82.3808706	total: 1.74s	remaining: 399ms
# 813:	learn: 82.3400423	total: 1.74s	remaining: 397ms
# 814:	learn: 82.2473314	total: 1.74s	remaining: 395ms
# 815:	learn: 82.1857536	total: 1.74s	remaining: 393ms
# 816:	learn: 82.1412958	total: 1.74s	remaining: 390ms
# 817:	learn: 82.0478168	total: 1.74s	remaining: 388ms
# 818:	learn: 81.9737376	total: 1.75s	remaining: 386ms
# 819:	learn: 81.9101837	total: 1.75s	remaining: 383ms
# 820:	learn: 81.9037901	total: 1.75s	remaining: 381ms
# 821:	learn: 81.8023969	total: 1.75s	remaining: 378ms
# 822:	learn: 81.7589242	total: 1.75s	remaining: 376ms
# 823:	learn: 81.7456836	total: 1.75s	remaining: 373ms
# 824:	learn: 81.6908614	total: 1.75s	remaining: 371ms
# 825:	learn: 81.6762305	total: 1.75s	remaining: 369ms
# 826:	learn: 81.6274127	total: 1.76s	remaining: 369ms
# 827:	learn: 81.6097534	total: 1.77s	remaining: 367ms
# 828:	learn: 81.5305778	total: 1.77s	remaining: 365ms
# 829:	learn: 81.4790563	total: 1.77s	remaining: 363ms
# 830:	learn: 81.4733190	total: 1.77s	remaining: 361ms
# 831:	learn: 81.4373628	total: 1.77s	remaining: 358ms
# 832:	learn: 81.3337392	total: 1.77s	remaining: 356ms
# 833:	learn: 81.2412380	total: 1.77s	remaining: 353ms
# 834:	learn: 81.1804130	total: 1.78s	remaining: 351ms
# 835:	learn: 81.1660210	total: 1.79s	remaining: 351ms
# 836:	learn: 81.1280019	total: 1.79s	remaining: 348ms
# 837:	learn: 81.0406017	total: 1.79s	remaining: 346ms
# 838:	learn: 81.0333884	total: 1.79s	remaining: 344ms
# 839:	learn: 80.9994885	total: 1.79s	remaining: 341ms
# 840:	learn: 80.9695787	total: 1.79s	remaining: 339ms
# 841:	learn: 80.9638851	total: 1.79s	remaining: 337ms
# 842:	learn: 80.8698317	total: 1.8s	remaining: 335ms
# 843:	learn: 80.8236449	total: 1.8s	remaining: 333ms
# 844:	learn: 80.7778671	total: 1.82s	remaining: 334ms
# 845:	learn: 80.7647583	total: 1.82s	remaining: 332ms
# 846:	learn: 80.7583842	total: 1.82s	remaining: 330ms
# 847:	learn: 80.6894384	total: 1.83s	remaining: 328ms
# 848:	learn: 80.6730221	total: 1.83s	remaining: 325ms
# 849:	learn: 80.6676644	total: 1.83s	remaining: 323ms
# 850:	learn: 80.5966447	total: 1.83s	remaining: 320ms
# 851:	learn: 80.5529953	total: 1.83s	remaining: 318ms
# 852:	learn: 80.5131808	total: 1.83s	remaining: 316ms
# 853:	learn: 80.4343451	total: 1.83s	remaining: 313ms
# 854:	learn: 80.3591779	total: 1.83s	remaining: 311ms
# 855:	learn: 80.3055560	total: 1.83s	remaining: 309ms
# 856:	learn: 80.2036006	total: 1.83s	remaining: 306ms
# 857:	learn: 80.1937491	total: 1.83s	remaining: 304ms
# 858:	learn: 80.1820321	total: 1.84s	remaining: 302ms
# 859:	learn: 80.0867038	total: 1.84s	remaining: 299ms
# 860:	learn: 79.9971449	total: 1.84s	remaining: 297ms
# 861:	learn: 79.9205845	total: 1.84s	remaining: 294ms
# 862:	learn: 79.8823186	total: 1.84s	remaining: 292ms
# 863:	learn: 79.8537782	total: 1.84s	remaining: 290ms
# 864:	learn: 79.7922946	total: 1.84s	remaining: 287ms
# 865:	learn: 79.6890273	total: 1.84s	remaining: 285ms
# 866:	learn: 79.6167488	total: 1.84s	remaining: 283ms
# 867:	learn: 79.5883553	total: 1.85s	remaining: 281ms
# 868:	learn: 79.5436863	total: 1.85s	remaining: 279ms
# 869:	learn: 79.4794419	total: 1.85s	remaining: 276ms
# 870:	learn: 79.4670761	total: 1.85s	remaining: 274ms
# 871:	learn: 79.4357421	total: 1.85s	remaining: 272ms
# 872:	learn: 79.4091190	total: 1.85s	remaining: 269ms
# 873:	learn: 79.3485286	total: 1.85s	remaining: 267ms
# 874:	learn: 79.2755830	total: 1.85s	remaining: 265ms
# 875:	learn: 79.2316388	total: 1.85s	remaining: 262ms
# 876:	learn: 79.1638242	total: 1.85s	remaining: 260ms
# 877:	learn: 79.1287615	total: 1.85s	remaining: 258ms
# 878:	learn: 79.0894838	total: 1.86s	remaining: 256ms
# 879:	learn: 79.0635803	total: 1.86s	remaining: 253ms
# 880:	learn: 79.0108685	total: 1.86s	remaining: 251ms
# 881:	learn: 78.9023739	total: 1.86s	remaining: 249ms
# 882:	learn: 78.8608782	total: 1.86s	remaining: 247ms
# 883:	learn: 78.7555818	total: 1.86s	remaining: 244ms
# 884:	learn: 78.7431063	total: 1.86s	remaining: 242ms
# 885:	learn: 78.6541057	total: 1.86s	remaining: 240ms
# 886:	learn: 78.5843118	total: 1.86s	remaining: 237ms
# 887:	learn: 78.5211358	total: 1.86s	remaining: 235ms
# 888:	learn: 78.5172611	total: 1.86s	remaining: 233ms
# 889:	learn: 78.4800406	total: 1.86s	remaining: 231ms
# 890:	learn: 78.4759931	total: 1.87s	remaining: 228ms
# 891:	learn: 78.4232139	total: 1.87s	remaining: 226ms
# 892:	learn: 78.3597167	total: 1.87s	remaining: 224ms
# 893:	learn: 78.3211459	total: 1.87s	remaining: 222ms
# 894:	learn: 78.2843901	total: 1.87s	remaining: 220ms
# 895:	learn: 78.2065139	total: 1.87s	remaining: 217ms
# 896:	learn: 78.1489740	total: 1.87s	remaining: 215ms
# 897:	learn: 78.1079441	total: 1.87s	remaining: 213ms
# 898:	learn: 78.0739047	total: 1.88s	remaining: 211ms
# 899:	learn: 78.0108686	total: 1.88s	remaining: 208ms
# 900:	learn: 77.9999198	total: 1.88s	remaining: 206ms
# 901:	learn: 77.9737356	total: 1.88s	remaining: 204ms
# 902:	learn: 77.9024937	total: 1.88s	remaining: 202ms
# 903:	learn: 77.8913142	total: 1.88s	remaining: 200ms
# 904:	learn: 77.7913906	total: 1.88s	remaining: 198ms
# 905:	learn: 77.7616937	total: 1.88s	remaining: 195ms
# 906:	learn: 77.7162527	total: 1.88s	remaining: 193ms
# 907:	learn: 77.6534853	total: 1.89s	remaining: 191ms
# 908:	learn: 77.6099238	total: 1.89s	remaining: 189ms
# 909:	learn: 77.6055201	total: 1.89s	remaining: 187ms
# 910:	learn: 77.5948033	total: 1.89s	remaining: 184ms
# 911:	learn: 77.5312799	total: 1.89s	remaining: 182ms
# 912:	learn: 77.4680302	total: 1.89s	remaining: 180ms
# 913:	learn: 77.4110596	total: 1.89s	remaining: 178ms
# 914:	learn: 77.3977772	total: 1.89s	remaining: 176ms
# 915:	learn: 77.3458903	total: 1.89s	remaining: 173ms
# 916:	learn: 77.3140101	total: 1.89s	remaining: 171ms
# 917:	learn: 77.2569984	total: 1.89s	remaining: 169ms
# 918:	learn: 77.2462606	total: 1.9s	remaining: 167ms
# 919:	learn: 77.1917418	total: 1.9s	remaining: 165ms
# 920:	learn: 77.1287504	total: 1.9s	remaining: 163ms
# 921:	learn: 77.0991970	total: 1.9s	remaining: 161ms
# 922:	learn: 77.0309724	total: 1.9s	remaining: 159ms
# 923:	learn: 76.9868077	total: 1.9s	remaining: 157ms
# 924:	learn: 76.9716674	total: 1.9s	remaining: 154ms
# 925:	learn: 76.9096221	total: 1.9s	remaining: 152ms
# 926:	learn: 76.8182781	total: 1.91s	remaining: 150ms
# 927:	learn: 76.7934019	total: 1.91s	remaining: 148ms
# 928:	learn: 76.7896300	total: 1.98s	remaining: 151ms
# 929:	learn: 76.7636865	total: 2.01s	remaining: 151ms
# 930:	learn: 76.7231307	total: 2.01s	remaining: 149ms
# 931:	learn: 76.6316340	total: 2.01s	remaining: 147ms
# 932:	learn: 76.5770937	total: 2.01s	remaining: 145ms
# 933:	learn: 76.5037198	total: 2.01s	remaining: 142ms
# 934:	learn: 76.4748442	total: 2.02s	remaining: 140ms
# 935:	learn: 76.4071520	total: 2.02s	remaining: 138ms
# 936:	learn: 76.4042173	total: 2.02s	remaining: 136ms
# 937:	learn: 76.3802468	total: 2.02s	remaining: 134ms
# 938:	learn: 76.3614600	total: 2.02s	remaining: 132ms
# 939:	learn: 76.3299908	total: 2.04s	remaining: 130ms
# 940:	learn: 76.3108099	total: 2.04s	remaining: 128ms
# 941:	learn: 76.2597585	total: 2.04s	remaining: 126ms
# 942:	learn: 76.2009231	total: 2.04s	remaining: 124ms
# 943:	learn: 76.1583289	total: 2.04s	remaining: 121ms
# 944:	learn: 76.1278071	total: 2.04s	remaining: 119ms
# 945:	learn: 76.1125464	total: 2.05s	remaining: 117ms
# 946:	learn: 76.0839143	total: 2.05s	remaining: 115ms
# 947:	learn: 76.0063313	total: 2.05s	remaining: 112ms
# 948:	learn: 75.9403190	total: 2.05s	remaining: 110ms
# 949:	learn: 75.8971182	total: 2.05s	remaining: 108ms
# 950:	learn: 75.8543848	total: 2.05s	remaining: 106ms
# 951:	learn: 75.7987645	total: 2.05s	remaining: 103ms
# 952:	learn: 75.7674912	total: 2.05s	remaining: 101ms
# 953:	learn: 75.7064951	total: 2.05s	remaining: 99.1ms
# 954:	learn: 75.6932706	total: 2.05s	remaining: 96.8ms
# 955:	learn: 75.6491861	total: 2.06s	remaining: 94.6ms
# 956:	learn: 75.5845913	total: 2.06s	remaining: 92.5ms
# 957:	learn: 75.5682771	total: 2.06s	remaining: 90.4ms
# 958:	learn: 75.5435957	total: 2.06s	remaining: 88.2ms
# 959:	learn: 75.4892386	total: 2.06s	remaining: 86ms
# 960:	learn: 75.4369823	total: 2.06s	remaining: 83.8ms
# 961:	learn: 75.3723420	total: 2.06s	remaining: 81.6ms
# 962:	learn: 75.3460659	total: 2.06s	remaining: 79.4ms
# 963:	learn: 75.3150465	total: 2.07s	remaining: 77.2ms
# 964:	learn: 75.2965767	total: 2.07s	remaining: 75ms
# 965:	learn: 75.2495819	total: 2.07s	remaining: 72.8ms
# 966:	learn: 75.2445934	total: 2.07s	remaining: 70.7ms
# 967:	learn: 75.2137142	total: 2.07s	remaining: 68.5ms
# 968:	learn: 75.1599199	total: 2.07s	remaining: 66.3ms
# 969:	learn: 75.0936642	total: 2.07s	remaining: 64.1ms
# 970:	learn: 75.0811863	total: 2.07s	remaining: 62ms
# 971:	learn: 75.0429096	total: 2.08s	remaining: 59.8ms
# 972:	learn: 75.0118483	total: 2.08s	remaining: 57.6ms
# 973:	learn: 74.9836723	total: 2.08s	remaining: 55.5ms
# 974:	learn: 74.9487698	total: 2.08s	remaining: 53.3ms
# 975:	learn: 74.8956539	total: 2.08s	remaining: 51.1ms
# 976:	learn: 74.8259790	total: 2.08s	remaining: 49ms
# 977:	learn: 74.7942274	total: 2.08s	remaining: 46.8ms
# 978:	learn: 74.7332971	total: 2.08s	remaining: 44.6ms
# 979:	learn: 74.7071931	total: 2.08s	remaining: 42.5ms
# 980:	learn: 74.6555419	total: 2.08s	remaining: 40.3ms
# 981:	learn: 74.6252281	total: 2.08s	remaining: 38.2ms
# 982:	learn: 74.6170660	total: 2.08s	remaining: 36.1ms
# 983:	learn: 74.5955389	total: 2.09s	remaining: 33.9ms
# 984:	learn: 74.5593666	total: 2.09s	remaining: 31.8ms
# 985:	learn: 74.4974069	total: 2.09s	remaining: 29.7ms
# 986:	learn: 74.4605849	total: 2.09s	remaining: 27.5ms
# 987:	learn: 74.4216828	total: 2.09s	remaining: 25.4ms
# 988:	learn: 74.3820075	total: 2.09s	remaining: 23.3ms
# 989:	learn: 74.3387870	total: 2.09s	remaining: 21.2ms
# 990:	learn: 74.2848273	total: 2.09s	remaining: 19ms
# 991:	learn: 74.2671399	total: 2.1s	remaining: 16.9ms
# 992:	learn: 74.2247658	total: 2.1s	remaining: 14.8ms
# 993:	learn: 74.1463452	total: 2.1s	remaining: 12.7ms
# 994:	learn: 74.1116216	total: 2.1s	remaining: 10.6ms
# 995:	learn: 74.0587503	total: 2.1s	remaining: 8.44ms
# 996:	learn: 74.0212771	total: 2.1s	remaining: 6.33ms
# 997:	learn: 73.9878812	total: 2.1s	remaining: 4.22ms
# 998:	learn: 73.9617333	total: 2.1s	remaining: 2.11ms
# 999:	learn: 73.8711340	total: 2.11s	remaining: 0us
# 평균: 112.91943764176008 | 표준편차: 14.79204947165533

# %% [markdown]
# ## Finalizing: Making submission file

# %%
submission = pd.DataFrame(columns=['code', 'num'])
submission['code']= X_test.index
submission['num']= pred2
error = pd.DataFrame(np.array([['C2675', 0], ['C2335', 0], ['C1327', 0]]), columns=['code', 'num'])
submission = pd.concat([submission, error]).reset_index(drop=True)

submission['num'] = submission['num'].astype('float64')
submission.loc[submission['num']<0,'num'] = 0
submission.to_csv('submission_cat_0729.csv', index=False)

# %%
submission
# Out:
#       code          num
# 0    C1072   773.382876
# 1    C1128  1238.803882
# 2    C1456   512.386256
# 3    C1840   517.606005
# 4    C1332  1166.899432
# 5    C1563  2173.124277
# 6    C1794   836.929293
# 7    C1640   480.064533
# 8    C1377   311.169160
# 9    C2072   301.748977
# 10   C1472   471.564384
# 11   C1006   274.149868
# 12   C1083   363.803731
# 13   C1311   168.347336
# 14   C2676   256.500743
# 15   C2318   216.346713
# 16   C1603   448.712633
# 17   C2523   286.106865
# 18   C2177   164.244278
# 19   C2411   634.459123
# 20   C2033   234.068497
# 21   C1604   318.187441
# 22   C2535   407.711387
# 23   C1040   377.679125
# 24   C2417   410.092476
# 25   C1812   102.027053
# 26   C2253   136.582229
# 27   C1294   498.992999
# 28   C1772   490.517245
# 29   C2646   534.342287
# 30   C1152   943.836976
# 31   C2423   160.790136
# 32   C1844   490.855041
# 33   C1318   187.954373
# 34   C1729   243.795256
# 35   C1602   304.990980
# 36   C1239   376.322263
# 37   C1721   616.261951
# 38   C1902   803.523090
# 39   C1855   293.685835
# 40   C2600   399.159285
# 41   C1071   519.938038
# 42   C2295   433.319701
# 43   C1621   560.327191
# 44   C1852   881.840996
# 45   C2555  1435.719710
# 46   C1297   492.328588
# 47   C2323   611.964617
# 48   C2215   423.667641
# 49   C2112   348.544102
# 50   C1830   852.016561
# 51   C2602   260.021862
# 52   C2608  1136.923455
# 53   C1215   584.391887
# 54   C2369   675.094224
# 55   C1158   262.475604
# 56   C1887   573.271455
# 57   C1189   200.233638
# 58   C1637   473.600643
# 59   C1225   192.782518
# 60   C2374   322.318130
# 61   C2397   594.468753
# 62   C1105  1032.752905
# 63   C1782   458.116895
# 64   C1629   215.244164
# 65   C1708   270.094460
# 66   C2144   506.756001
# 67   C1617   952.971830
# 68   C1149   579.380987
# 69   C1323   475.691566
# 70   C1064   786.153296
# 71   C1019   273.237803
# 72   C2269   595.949800
# 73   C1416   909.938661
# 74   C1250  1018.166966
# 75   C1741   459.562940
# 76   C1016   658.657431
# 77   C2436   609.649115
# 78   C2039  1007.342901
# 79   C1253   931.591185
# 80   C2028  1152.224484
# 81   C1166   358.645530
# 82   C1135   259.815616
# 83   C1216   273.505604
# 84   C1593   238.034851
# 85   C1826   252.257765
# 86   C1827   454.309532
# 87   C1564   310.328748
# 88   C1495   906.243912
# 89   C2653   975.897881
# 90   C1392   631.720037
# 91   C2128   323.816883
# 92   C1282   508.921370
# 93   C1521   922.183628
# 94   C2076   864.684728
# 95   C1060   580.683933
# 96   C2473  1092.259358
# 97   C2557   773.201476
# 98   C1835   815.899170
# 99   C2224   709.696371
# 100  C2222   394.262631
# 101  C2430  1062.238257
# 102  C2497   738.140677
# 103  C1494  1046.398545
# 104  C1457   418.007943
# 105  C1525  1261.615738
# 106  C1712   640.243151
# 107  C2267   925.761663
# 108  C1623   308.059744
# 109  C2131   593.314523
# 110  C2691  1142.983463
# 111  C1147   889.462529
# 112  C1692   969.547997
# 113  C1570   764.224205
# 114  C1474   112.042371
# 115  C1633   194.062280
# 116  C2113   540.763099
# 117  C2175   917.194581
# 118  C2303  1405.754637
# 119  C2547   558.739047
# 120  C2292   866.980860
# 121  C1496   807.108541
# 122  C1289   384.080659
# 123  C1849   687.576107
# 124  C1003   197.219805
# 125  C2268   369.563502
# 126  C2551   661.371018
# 127  C2688   107.591799
# 128  C1030    76.825168
# 129  C2451   615.975393
# 130  C1749   440.936271
# 131  C1349   213.464600
# 132  C2043   184.108155
# 133  C1229   290.545510
# 134  C2363   428.234502
# 135  C1414   413.889809
# 136  C2174   348.525039
# 137  C2091   131.566858
# 138  C1841    73.748152
# 139  C2404    63.567261
# 140  C1683   138.536999
# 141  C1038   283.549147
# 142  C2456   218.410327
# 143  C1266   442.319902
# 144  C2152    22.939439
# 145  C1267   374.724582
# 146  C2189    75.298061
# 147  C2675     0.000000
# 148  C2335     0.000000
# 149  C1327     0.000000

# %% [markdown]
# #### feature selection 안한 ver. public score :87.2994749246
#
# ---
# ---
